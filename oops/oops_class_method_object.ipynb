# %%
a=5
type(a)
# Out:
# int

# %%
a=5
print(type(a))
# Out:
# <class 'int'>

# %%
l=[1,2,4]
print(type(l))
# Out:
# <class 'list'>

# %%
def config():
    print("hello team")
config()
# Out:
# hello team

# %%
class laptop(): # laptop is class name
    def config(): # config is method name
        print("hello team") # statement
lap=laptop() # lab - object

# %%
class laptop():
    def config():
        print("hello team")
lap=laptop()
laptop.config()
# Out:
# hello team

# %%
class laptop():
    def config():
        print("hello team")

lap=laptop()
lap.config()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 6
#       3         print("hello team")
#       5 lap=laptop()
# ----> 6 lap.config()
#
# TypeError: laptop.config() takes 0 positional arguments but 1 was given

# %%
class laptop():
    def config(self):
        print("hello team")

lap=laptop()
lap.config()
# Out:
# hello team

# %%
class laptop():
    def config(self):
        print("hello team")
lap=laptop()
lap1=laptop()
lab2=laptop()

lap.config()
lap1.config()
lab2.config()
# Out:
# hello team
# hello team
# hello team

# %%
class computer(): # computer is the class
    def config(self): # config is the method
        print("i5","8gb")

com1=computer()
com2=computer()
com3=computer()

print(id(com1))
print(id(com2))
print(id(com3))
# Out:
# 1859537921392
# 1859537918848
# 1859537916016

# %%
class computer(): #computer is class (user the class here(user define class))
    def lap():#confit is method (define some method hear so when we talk class always method will come ( so dont talk about function here)
        print('i5','8gb') # i want to print configuration of the machine which i5 ram & 8gb ram
a= '2.2'
print(type(a))

com1=computer() #com1 is the user define object of the computer class but if you check above a is the object for string data type & in java we called this as const
print(type(com1))
# Out:
# <class 'str'>
# <class '__main__.computer'>

# %% [markdown]
# # Special Method

# %%
class computer():
    def __init__(self):
        print('i5','8gb')
com1=computer()
com2=computer()
# Out:
# i5 8gb
# i5 8gb

# %%
class computer():
    def __init__(self):
        print('i5','8gb')

com1=computer()
com2=computer()

com1. __init__()
# Out:
# i5 8gb
# i5 8gb
# i5 8gb

# %%
class computer:
    def __init__(self): #__init__means initialize the varible
        print('in init')

com1=computer()
com2=computer()
com3=computer()
# Out:
# in init
# in init
# in init

# %%
class computer():
    def __init__(self): #__init__ means initialize the varible
        print('in init')

    def computer(self):
        print('i5',8)
com1=computer()
# Out:
# in init

# %%
class computer():
    def __init__(self): #__init__means initialize the varible
        print('in init')

    def computer(self):
        print('i5',8)

com1=computer()
com1.computer()
# Out:
# in init
# i5 8

# %%
class computer():
    def config(self):
        print('i5','8gb')

    def config2(self):
        print('i7','32gb')

    def __init__(self):
        print('in init')

com1=computer()
com2=computer()

com1.config()
com1.config2()
# Out:
# in init
# in init
# i5 8gb
# i7 32gb

# %%
class computer():
    def __init__(self): # __init__means to initialize the variable
        print('in init')
    def config(self):
        print('i5','8gb')

com1=computer('i5',8,200000) # com1 has cpu i5 & ram is 8
com1.config()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[44], line 7
#       4     def config(self):
#       5         print('i5','8gb')
# ----> 7 com1=computer('i5',8,200000) # com1 has cpu i5 & ram is 8
#       8 com1.config()
#
# TypeError: computer.__init__() takes 1 positional argument but 4 were given

# %%
class computer():
    def __init__(self): # __init__means to initialize the variable
        print('in init')
    def config(self):
        print('i5','8gb')

com1=computer('i5',8,200000) # com1 has cpu i5 & ram is 8
com2=computer('i7',16) #com2 has cpu intel 5 is 8 as we have computer we have different ram

com1.config()
com2.config()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 7
#       4     def config(self):
#       5         print('i5','8gb')
# ----> 7 com1=computer('i5',8,200000) # com1 has cpu i5 & ram is 8
#       8 com2=computer('i7',16) #com2 has cpu intel 5 is 8 as we have computer we have different ram
#      10 com1.config()
#
# TypeError: computer.__init__() takes 1 positional argument but 4 were given

# %%
class computer():
    def __init__(self,cpu,ram,price): # __init__means to initialize the variable
        print('in init')
    def config(self):
        print('i5','8gb',5000)

com1=computer('i5',8,200000) # com1 has cpu i5 & ram is 8
com2=computer('i7',16,60000) #com2 has cpu intel 5 is 8 as we have computer we have different ram

com1.config()
com2.config()
# Out:
# in init
# in init
# i5 8gb 5000
# i5 8gb 5000

# %%
class computer():
    def __init__(self,cpu,ram): # cpu & ram as argument
        self.cpu=cpu # here self is the object & we need to refer to the object
        self.ram=ram
    def config(self):
        print('config is',self.cpu,self.ram)

com1=computer('i5',8)
com2=computer('i7',16)

com1.config()
com2.config()
# Out:
# config is i5 8
# config is i7 16

# %%
class computer():
    def __init__(self,cpu,ram,price): # cpu & ram as argument
        self.cpu=cpu # here self is the object & we need to refer to the object
        self.ram=ram
        self.price=price
    def config(self):
        print('config is',self.cpu,self.ram,self.price)

com1=computer('i5',8,1000)
com2=computer('i7',16,2000)

com1.config()
com2.config()
# Out:
# config is i5 8 1000
# config is i7 16 2000

# %%
class computer():
    def __init__(self,cpu,ram,price,company): # cpu & ram as argument
        self.cpu=cpu # here self is the object & we need to refer to the object
        self.ram=ram
        self.price=price
        self.company=company
        
    def config(self):
        print('config is',self.cpu,self.ram,self.price,self.company)

com1=computer('i5',8,1000,'lenovo')
com2=computer('i7',16,2000,'hp')

com1.config()
com2.config()
# Out:
# config is i5 8 1000 lenovo
# config is i7 16 2000 hp

# %%
class computer():
    def __init__(self):
        self.name='swati'
        self.age=22

c1=computer()
c2=computer()

print(c1.name,c1.age)
print(c2.name)
# Out:
# swati 22
# swati

# %%
class computer():
    def __init__(self):
        self.name='swati'
        self.age=22

c1=computer()
c2=computer()

c2.name='ankita'
c2.age=23
c1.age=20

print(c1.name,c1.age)
print(c2.name,c2.age)
# Out:
# swati 20
# ankita 23

# %% [markdown]
# # Instance variable

# %%
class car:
    def __init__(self):
        self.mil=10
        self.com='bmw'

c1=car()
c2=car()

print(c1.com,c1.mil)
print(c2.com,c2.mil)
# Out:
# bmw 10
# bmw 10

# %%
class car:
    def __init__(self):
        self.mil=10
        self.com='bmw'

c1=car()
c2=car()

c1.mil = 9
c2.mil = 5

print(c1.com,c1.mil)
print(c2.com,c2.mil)
# Out:
# bmw 9
# bmw 5

# %%
class car:
    def __init__(self):
        self.mil=10
        self.com='bmw'

c1=car()
c2=car()

c1.mil = 9
c2.mil = 18
c2.com = 'asian_cars'

print(c1.com,c1.mil)
print(c2.com,c2.mil)
# Out:
# bmw 9
# asian_cars 18

# %%
class car:
    wheels = 5 # class variable or static variable
    def __init__(self):
        self.mil = 10 # instance variable
        self.com = 'bmw' # instance variable

c1 = car()
c2 = car()

c1.wheels = 6

print(c1.wheels, c1.com)
# Out:
# 6 bmw

# %% [markdown]
# # Encapsulation -- methods

# %%
class student():
    school = 'nit'

    def __init__(self,m1,m2,m3):
        self.m1 = m1
        self.m2 = m2
        self.m3 = m3

    def avg(self): #-----> hear this average is instance method
        return (self.m1+self.m2+self.m3)/3

s1 = student(10,20,30)
s2 = student(5,15,10)

print(s1.avg())
print(s2.avg())
# Out:
# 20.0
# 10.0

# %%
class student:
    school='nit'
    def __init__(self,m1,m2,m3): # hear i pass variable
        self.m1=m1
        self.m2=m2
        self.m3=m3

    def avg(self): # -----> hear this average is instance method
        return(self.m1+self.m2+self.m3)/3

# lets create object hear as we created s1,s2 we created 2 object and also i want to pass value in
s1=student(10,20,30)
s2=student(5,15,10)

print(s1.avg())
print(s2.avg())
# Out:
# 20.0
# 10.0

# %%
class student:
    school='nit'
    def __init__(self,m1,m2,m3): # hear i pass variable
        self.m1=m1
        self.m2=m2
        self.m3=m3

    def avg(self): # -----> hear this average is instance method
        return(self.m1+self.m2+self.m3)/3

    def info(cls): # user need to define cls - for class variable
        return cls.school

# lets create object hear as we created s1,s2 we created 2 object and also i want to pass value in
s1=student(10,20,30)
s2=student(5,15,10)

print(s1.avg()) # instance method it calls instance variable
print(s1.info()) # class method cuz it call variable
# Out:
# 20.0
# nit

# %%
class student:
    school='nit'
    def __init__(self,m1,m2,m3): # hear i pass 3 variable
        self.m1=m1
        self.m2=m2
        self.m3=m3

    def avg(self): # -------> hear this average is instance method
        return(self.m1+self.m2+self.m3)/3
    # classmethod
    def info(cls): # user need to define cls - for class variable
        return cls.school

s1=student(10,20,30)
s2=student(5,15,10)

s1.info()
s2.avg()
# Out:
# 10.0

# %%
class student:
    school='nit'
    def __init__(self,m1,m2,m3): # hear i pass 3 variable
        self.m1=m1
        self.m2=m2
        self.m3=m3

    def avg(self): # -------> hear this average is instance method
        return(self.m1+self.m2+self.m3)/3
    @classmethod
    def info(cls): # user need to define cls - for class variable
        return cls.school

    @staticmethod # this student class nothing to do any class & for that also u need to pass special 
    def info():
         print('This is student class')

s1=student(10,20,30)
s2=student(5,15,10)


s1.avg()
# Out:
# 20.0

# %% [markdown]
# # Outer class vs inner class

# %%
class student:
    def __init__(self,name,rollno):
        self.name=name
        self.rollno=rollno
s1=student('a',1)
s2=student('b',2)

print(s1.name,s1.rollno)
print(s2.name,s2.rollno)
# Out:
# a 1
# b 2

# %%
class student:
    def __init__(self,name,rollno):
        self.name=name
        self.rollno=rollno

    def show(self):
        print(s1.name,s1.rollno)
        print(s2.name)
        
s1=student('a',1)
s2=student('b',2)

s1.show()
# Out:
# a 1
# b

# %%
class student:
    def __init__(self,name,rollno):
        self.name=name
        self.rollno=rollno

    def show(self):
        print(s1.name,s1.rollno)
        print(s2.name)
        
s1=student('a',1,'hp','i5',8) # the moment when we assign the variable we need to assign the class a
s2=student('b',2)

s1.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[3], line 10
#       7         print(s1.name,s1.rollno)
#       8         print(s2.name)
# ---> 10 s1=student('a',1,'hp','i5',8) # the moment when we assign the variable we need to assign the class a
#      11 s2=student('b',2)
#      13 s1.show()
#
# TypeError: student.__init__() takes 3 positional arguments but 6 were given

# %%
class student:
    def __init__(self,name,rollno,laptop,cpu,ram):
        self.name=name
        self.rollno=rollno
        self.laptop=laptop
        self.cpu=cpu
        self.ram=ram

    def show(self):
        print(s1.name,s1.rollno,s1.laptop,s1.cpu,s1.ram)
        print(s2.name,s2.rollno,s2.laptop,s2.cpu,s2.ram)
        
s1=student('a',1,'hp','i5',8) # the moment when we assign the variable we need to assign the class a
s2=student('b',2,'hp','i7',16)

s1.show()
# Out:
# a 1 hp i5 8
# b 2 hp i7 16

# %%
class student:
    def __init__(self,name,rollno):
        self.name=name
        self.rollno=rollno

    def show(self):
        print(self.name,self.rollno)

    class laptop:
        def __init__(self):
            self.brand='hp'
            self.cpu='i5'
            self.ram=8

s1=student('a',1) # the moment when we assign the variable we need to assign the class
s2=student('b',2)

s1.show()
s2.show()
# Out:
# a 1
# b 2

# %%
class student:
    def __init__(self, name, rollno):
        self.name = name
        self.rollno = rollno
        
        self.lap = self.LAPTOP()
        
    def show(self):
        print(self.name, self.rollno)
        
    class LAPTOP:
        def __init__(self):
            self.brand = 'hp'
            self.cpu = 'i5'
            self.ram = 8
     
s1 = student('a',1) # the moment when we assign the variable we need to assign the class as well 
s2 = student('b',2)

s1.show()
s2.show()


lap1 = s1.lap
lap2 = s2.lap

print(id(lap1))
print(id(lap2))
# Out:
# a 1
# b 2
# 2102457170640
# 2102457170016

# %%
class student:
    def __init__(self, name, rollno):
        self.name = name
        self.rollno = rollno
        
        self.lap = self.LAPTOP()
        
    def show(self):
        print(self.name, self.rollno)
        
    class LAPTOP:
        def __init__(self):
            self.brand = 'avita'
            self.cpu = 'i5'
            self.ram = 8
     
s1 = student('a',1) # the moment when we assign the variable we need to assign the class as well 
s2 = student('b',2)

s1.show()
s2.show()


lap1 = s1.lap
lap2 = s2.lap
lap3=s2.lap.brand

print(lap1)
print(lap2)
print(lap3)
# Out:
# a 1
# b 2
# <__main__.student.LAPTOP object at 0x000001E9FB519A30>
# <__main__.student.LAPTOP object at 0x000001E98436F830>
# avita

# %% [markdown]
# # Inheritence

# %%
class A():
    def feature1(self):
        print('feature1 is hi')
    def feature2(self):
        print('feature2 is hi')

a1=A()
a1.feature2()
# Out:
# feature2 is hi

# %%
class A():
    def feature1(self):
        print('feature1 is hi')
    def feature2(self):
        print('feature2 is hi')

class B(A):
    def feature3(self):
        print('feature3 is hello')
    def feature4(self):
        print('feature is hello')

    

a1=A()
b1=B()
b1.feature1()
# Out:
# feature1 is hi

# %%
class A():
    def feature1(self):
        print('feature1 is hi')
    def feature2(self):
        print('feature2 is hi')

class B(A):
    def feature3(self):
        print('feature3 is hello')
    def feature4(self):
        print('feature4 is hello')

class C(B):
    def feature5():
        print('feature5 is welcom')

class D(C):
    print('feature')

a1=A()
b1=B()
c1=C()

c1.feature1()
# Out:
# feature
# feature1 is hi

# %%
class A():
    def feature1(self):
        print('feature1 is hi')
    def feature2(self):
        print('feature2 is hi')

class B():
    def feature3(self):
        print('feature3 is hello')
    def feature4(self):
        print('feature4 is hello')

class C(A,B):
    def feature5():
        print('feature5 is welcom')


a1=A()
b1=B()
c1=C()

c1.feature1()
# Out:
# feature1 is hi

# %% [markdown]
# # Constructor in inheritence

# %%
class A():
    def __init__(self):
        print('in a init')
    def feature1(self):
        print('feature1 is hi')
    def feature2(self):
        print('feature2 is hello')


class B():
    def feature4(self):
        print('feature3 is hello')
    def feature4(self):
        print('feature4 is hello')

a1=A()
b1=B()
# Out:
# in a init

# %%
class A():
    def __init__(self):
        print('in a init')
    def feature1(self):
        print('feature1 is hi')
    def feature2(self):
        print('feature2 is hello')


class B(A):
    def feature4(self):
        print('feature3 is hello')
    def feature4(self):
        print('feature4 is hello')

a1=A()
b1=B()
# Out:
# in a init
# in a init

# %%
class A():
    def __init__(self):
        print('in a init')
    def feature1(self):
        print('feature1 is hi')
    def feature2(self):
        print('feature2 is hi')

class B(A):
    def __init__(self):
        super(). __init__()
        print('in b init')
    def feature3(self):
        print('feature3 is hello')
    def feature4(self):
        print('feature4 is hello')

b1=B()
# Out:
# in a init
# in b init

# %%
class A():
    def __init__(self):
        print('in a init')
    def feature1(self):
        print('feature1 is hi')
    def feature2(self):
        print('feature2 is hi')

class B():
    def __init__(self):
        super(). __init__()
        print('in b init')
    def feature3(self):
        print('feature3 is hello')
    def feature4(self):
        print('feature4 is hello')

class C(A,B):
    def __init__(self):
        super().__init__()
        print('in the c init')

c1=C()
# Out:
# in a init
# in the c init

# %% [markdown]
# # Duck Typing

# %%
class duck():
    def swim(self):
        print('i am duck & i can swim')
    def speaks(self):
        print('quack quack')

class dog():
    def swim(self):
        print('i am dog & i can swim')
    def speaks(self):
        print('woof woof')

def display(duck): # we define outside of the class
    duck.swim()
    duck.speaks()

d=duck()
display(d)
# Out:
# i am duck & i can swim
# quack quack

# %%
class duck:
    def swim(self):
        print('i am duck & i can swim')
    def speaks(self):
        print('quack quack')

class dog:
    def swim(self):
        print('i am dog & i can swim')
    def speaks(self):
        print('woof woof')

def display(duck): # we define outside of the class
    duck.swim()
    duck.speaks()
   

d=duck
dg=dog()

display(dg)
# Out:
# i am dog & i can swim
# woof woof

# %%
class duck:
    def swim(self):
        print('i am duck & i can swim')
    def speaks(self):
        print('quack quack')

class dog:
    def swim(self):
        print('i am dog & i can swim')
    def speaks(self):
        print('woof woof')

class person:
    def speaks(self):
        print('attend more interview to get placed')
    
def display(obj): # we define outside of the class
    obj.swim()
    obj.speaks()
    obj.person()
   

d=duck()
dg=dog()
p=person()

display(p)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 27
#      24 dg=dog()
#      25 p=person()
# ---> 27 display(p)
#
# Cell In[3], line 18, in display(obj)
#      17 def display(obj): # we define outside of the class
# ---> 18     obj.swim()
#      19     obj.speaks()
#      20     obj.person()
#
# AttributeError: 'person' object has no attribute 'swim'

# %%
class duck:
    def swim(self):
        print('i am duck & i can swim')
    def speaks(self):
        print('quack quack')
    def walk(self):
        print('walk')

class dog:
    def swim(self):
        print('i am dog & i can swim')
    def speaks(self):
        print('woof woof')
    def walk(self):
        print('walk')

class person:
    def speaks(self):
        print('attend more interview to get placed')
    def swim(self):
        print('need to learn for swimming')
    def walk(self):
        print('walk')
    
def display(obj): # we define outside of the class
    obj.swim()
    obj.speaks()
    obj.walk()
   

d=duck()
dg=dog()
p=person()

display(p)
# Out:
# need to learn for swimming
# attend more interview to get placed
# walk

# %% [markdown]
# # Operator Overloading in python

# %%
a,b=5,6

print(type(a))
print(a+b)
# Out:
# <class 'int'>
# 11

# %%
int.__add__(a,b)
# Out:
# 11

# %%
int.__sub__(a,b)
# Out:
# -1

# %%
int.__mul__(a,b)
# Out:
# 30

# %%
class student:
    def __init__(self,m1,m2):
        self.m1=m1
        self.m2=m2
s1=student(60,70)
s2=student(80,90)

s3=s1+s2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 8
#       5 s1=student(60,70)
#       6 s2=student(80,90)
# ----> 8 s3=s1+s2
#
# TypeError: unsupported operand type(s) for +: 'student' and 'student'

# %%
class student:
    def __init__(self,m1,m2):
        self.m1=m1
        self.m2=m2
    def __add__(self,other): #we define the add method. this concept is called operator overloding
        m1=self.m1+other.m1
        m2=self.m2+other.m2
        s3=student(m1,m2)

        return s3
s1=student(60,70)
s2=student(80,90)

s3=s1+s2

print(s3.m1)
print(s3.m2)
# Out:
# 140
# 160

# %%
class student:
    def __init__(self,m1,m2):
        self.m1=m1
        self.m2=m2
    def __add__(self,other): #we define the add method. this concept is called operator overloding
        m1=self.m1+other.m1
        m2=self.m2+other.m2
        s3=student(m1,m2)

        return s3
        
s1=student(60,70)
s2=student(80,90)

s3=s1+s2

# We can also compare 2 object are > or less then
if s1>s2:
    print('s1 pass')
else:
    print('s2 pass')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[20], line 18
#      15 s3=s1+s2
#      17 # We can also compare 2 object are > or less then
# ---> 18 if s1>s2:
#      19     print('s1 pass')
#      20 else:
#
# TypeError: '>' not supported between instances of 'student' and 'student'

# %%
class student:
    def __init__(self,m1,m2):
        self.m1=m1
        self.m2=m2
    def __add__(self,other): #we define the add method. this concept is called operator overloding
        m1=self.m1+other.m1
        m2=self.m2+other.m2
        s3=student(m1,m2)

        return s3

    def __gt__(self,other):
        r1=self.m1+self.m2
        r2=other.m1+other.m2
        if r1>r2:
            return True
        else:
            return False
        
s1=student(60,70)
s2=student(80,90)

s3=s1+s2

# We can also compare 2 object are > or less then
if s1>s2:
    print('s1 pass')
else:
    print('s2 pass')
# Out:
# s2 pass

# %% [markdown]
# # Method Overloading

# %%
class demo():
    def add(self,a,b):
        return a+b
d=demo()
print(d.add(2,3))
# Out:
# 5

# %%
class demo():
    
    def add(self,a,b):
        return a+b
        
    def add(self, a, b, c):
        return a + b + c

    def add(self, a, b, c, d):
        return a + b + c + d

d = demo()
print(d.add(2,3))
print(d.add(2,3,4))
print(d.add(2,3, 4, 5))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[27], line 13
#      10         return a + b + c + d
#      12 d = demo()
# ---> 13 print(d.add(2,3))
#      14 print(d.add(2,3,4))
#      15 print(d.add(2,3, 4, 5))
#
# TypeError: demo.add() missing 2 required positional arguments: 'c' and 'd'

# %%
class demo():
    
    def add(self,a,b,c=0,d=0):
        return a+b+c+d
        

d = demo()
print(d.add(2,3))
print(d.add(2,3,4))
print(d.add(2,3, 4, 5))
# Out:
# 5
# 9
# 14

# %%
class demo():
    
    def add(self, *arg):
        total = 0
        for i in arg:
            total = total + i
        return total

d = demo()

print(d.add(2,3))
print(d.add(4,5,6))
print(d.add(1,2,3,4,5,6,))
# Out:
# 5
# 15
# 21

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2
        
    def sum(self, a=None, b=None,c=None):
        if a!=None and b!=None and c!=None:
            s = a + b +c
        elif a!=None and b!=None:
            s = a+b
        elif a!= None and c!= None:
            s = a + c
        else:
            s = a
            
        return s
    
s1 = student(50, 60)

print(s1.sum(10)) # hear we can pass 1 parameter
print(s1.sum(10,20)) # hear we can pass 2 parameter
print(s1.sum(10,20,30)) # hear we can pass 3 parameter
print(s1.sum(10,30))

#print(s1.sum(10,20,30,40))

# THIS CONCEPT CALLED AS METHOD OVERLOADING
# Out:
# 10
# 30
# 60
# 40

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2
        
    def sum(self, a=None, b=None,c=None):
        if a!=None and b!=None and c!=None:
            s = a + b +c
        elif a!=None and b!=None:
            s = a+b
        elif a!= None and c!= None:
            s = a + c
        else:
            s = a
            
        return s
    
s1 = student(50, 60)

print(s1.sum(10)) # hear we can pass 1 parameter
print(s1.sum(10,20)) # hear we can pass 2 parameter
print(s1.sum(10,20,30)) # hear we can pass 3 parameter
print(s1.sum(10,30))


# THIS CONCEPT CALLED AS METHOD OVERLOADING
# Out:
# 10
# 30
# 60
# 40

# %%
class student:
    def __init__(self,m1,m2):
        self.m1 = m1
        self.m2 = m2
        
    def sum(self, a=None, b=None,c=None):
        if a!=None and b!=None and c!=None:
            s = a + b +c
        elif a!=None and b!=None:
            s = a+b
        elif a!= None and c!= None:
            s = a + c
        else:
            s = a
            
        return s
    
s1 = student(50, 60)

print(s1.sum(10)) # hear we can pass 1 parameter
print(s1.sum(10,20)) # hear we can pass 2 parameter
print(s1.sum(10,20,30)) # hear we can pass 3 parameter
print(s1.sum(10,30))
print(s1.sum(10,20,30,40))

# THIS CONCEPT CALLED AS METHOD OVERLOADING
# Out:
# 10
# 30
# 60
# 40
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[49], line 24
#      22 print(s1.sum(10,20,30)) # hear we can pass 3 parameter
#      23 print(s1.sum(10,30))
# ---> 24 print(s1.sum(10,20,30,40))
#
# TypeError: student.sum() takes from 1 to 4 positional arguments but 5 were given

# %% [markdown]
# # Method Overriding

# %%
class A:
    def show(self):
        print('in a show')

s1=A()
s1.show()
# Out:
# in a show

# %%
class A:
    def show(self):
        print('in A show')

class B:
    pass

S1=A()
S1.show()
# Out:
# in A show

# %%
class A:
    def show(self):
        print('in a show')

class B(A):
    pass

s1=B()
s1.show()
# Out:
# in a show

# %%
class A():  # --------------- parent class 
    def show(self):
        print('in A show')
        
class B(): #-------------------child class 
    pass
        
s1 = A()
s1.show()
# Out:
# in A show

# %%
class A():  # --------------- parent class 
    def show(self):
        print('in A show')
        
class B(A): #-------------------child class 
    pass
        
s2 = B()
s2.show()
# Out:
# in A show

# %% [markdown]
# # Abstract Class and Abstract Method in python

# %%
class computer():
    def process(self): # declaration 
        print('running')   # defination

# %%
class computer():
    def process(self):
        pass
